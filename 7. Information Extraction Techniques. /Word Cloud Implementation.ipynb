# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

txt = '''
Lionel Messi is widely considered one of the greatest footballers of all time. Here are some key notes about him:

Career Highlights:
Seven Ballon d'Or awards (record): 2009, 2010, 2011, 2012, 2015, 2019, 2021
One Olympic gold medal (2008)
One FIFA World Cup (2022)
Four UEFA Champions League titles (2006, 2009, 2011, 2015)
Ten La Liga titles with Barcelona
All-time leading goalscorer for Barcelona (672) and Argentina (106)
Known for his exceptional dribbling, passing, and goalscoring abilities
Playing Style:
Primarily a left-winger, often described as a "false 9" due to dropping deep
Renowned for his close control, agility, and creativity
Possesses a powerful left foot and accurate finishing
Considered a playmaker and goalscorer in equal measure
Personality:
Humble and reserved demeanor
Dedicated to his team and sport
Highly respected by teammates and opponents alike
Role model for young footballers around the world
Impact:
Inspired millions of fans globally
Elevated the standard of football with his incredible talent
Transcended the sport to become a cultural icon
Additional Notes:

Messi began his professional career at Barcelona at the age of 17.
He spent his entire professional career at Barcelona until joining Paris Saint-Germain in 2021.
He is a vocal advocate for children's charities and has his own foundation.
Despite his global fame, he remains grounded and maintains a close relationship with his family and hometown.
'''
wc = WordCloud().generate(txt)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Word Cloud in Detail

# %%
from nltk.corpus import stopwords
# Will remove the stopwords from the cloud
stopword = stopwords.words('english')
stopword.append('footballers')
wc = WordCloud(width=1080,height=720,margin=2,max_words=100,background_color='white',stopwords=stopword)

plt.imshow(wc.generate(text))
plt.axis('off')
plt.show()
